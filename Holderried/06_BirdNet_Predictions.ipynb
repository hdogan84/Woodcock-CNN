# %% [markdown]
# ###Env to use: birdnet

# %%
import librosa
from skimage import feature
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import soundfile as sf
import os
from pathlib import Path
from sklearn.metrics import average_precision_score

# %%
from birdnetlib import Recording
from birdnetlib.analyzer import Analyzer
from datetime import datetime

# Load and initialize the BirdNET-Analyzer models.
analyzer = Analyzer()
# Out:
# c:\Users\dgnhk\anaconda3\envs\birdnet\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# WARNING:tensorflow:From c:\Users\dgnhk\anaconda3\envs\birdnet\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Labels loaded.
# load model True
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.

# %% [markdown]
# Predict for positive segments first

# %%
output_folder='../data/Holderried/selections_wavs/'
wav_files = os.listdir(output_folder)

# %%
predictions = dict.fromkeys(wav_files, 0.0)

# %%
for file in wav_files:
    audio_path = Path(os.path.join(output_folder, file))
    recording = Recording(
        analyzer,
        audio_path,
        min_conf=0.0
    )
    recording.analyze()
    for detection in recording.detections:
        if detection['scientific_name']=='Scolopax rusticola':
            predictions[file] = detection['confidence']
# Out:
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 10.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1000.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1001.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1002.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1003.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1004.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1005.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1006.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1007.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1008.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1010.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1011.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1012.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1013.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1014.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1017.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1018.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1019.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1020.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1021.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1022.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1023.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1024.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1025.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1027.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1028.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1029.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1030.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1031.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1032.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1033.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1034.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1098.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1099.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1100.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1101.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1102.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1103.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1104.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1105.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1106.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1107.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1108.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1109.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1110.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1111.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1112.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1113.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11135.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11136.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11137.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11138.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1114.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11140.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11141.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11142.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11143.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11144.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11145.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11146.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11147.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11148.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11149.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1115.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11150.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11151.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11152.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11154.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11155.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11156.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11157.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11158.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11159.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11160.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11161.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11162.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11163.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11164.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11165.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11166.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11167.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11168.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11169.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11170.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11171.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11172.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11173.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11174.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11175.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11176.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11177.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11178.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11179.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1118.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11180.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11181.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11182.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11183.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11184.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11185.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11186.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11187.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11188.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11189.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1119.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11190.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11191.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11192.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11193.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11194.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11195.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11196.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11197.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11198.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11199.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1120.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11200.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11201.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11202.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11203.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11204.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11205.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11206.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11207.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11208.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11209.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1121.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11210.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11211.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11212.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11213.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11214.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11215.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11216.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11219.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1122.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11220.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11221.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11222.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11223.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11224.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11225.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11226.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11227.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11228.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11229.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1123.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11230.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11231.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11232.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11234.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11235.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11236.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11237.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11238.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11239.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1124.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11240.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11241.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11242.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11243.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11244.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11245.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11246.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11247.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11248.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11249.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1125.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11250.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11251.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11252.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11253.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11254.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11255.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11256.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11257.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11258.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11259.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1126.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11260.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11261.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11267.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11268.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11269.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1127.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11270.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11271.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11272.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11273.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1128.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11280.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11281.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 11282.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1129.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1130.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1131.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1132.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1133.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1134.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1136.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1137.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1138.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1139.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1140.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1142.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1143.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1144.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1145.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1146.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1147.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1149.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1150.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1151.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1152.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1153.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1154.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1155.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1156.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1157.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1158.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1159.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1160.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1161.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1162.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1163.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1164.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1165.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1166.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1167.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1168.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 12.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 124.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 125.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 13.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 131.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 132.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 133.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 134.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 135.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 136.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 137.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 138.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 139.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 145.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 146.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 147.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 148.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 149.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1490.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1491.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1492.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1493.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1494.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1495.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1498.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1499.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 150.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1500.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1501.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1502.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 1503.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 
wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 894.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 895.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 896.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 897.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 898.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 899.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 9.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 900.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 901.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 902.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 903.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 905.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 906.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 907.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 908.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 909.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 910.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 911.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 912.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 913.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 914.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 915.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 916.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 917.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 918.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 919.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 920.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 921.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 922.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 923.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 924.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 925.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 926.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 927.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 928.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 929.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 930.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 931.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 934.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 935.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 936.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 937.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 938.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 939.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 940.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 941.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 942.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 943.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 944.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 945.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 946.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 947.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 948.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 949.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 950.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 951.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 952.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 953.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 954.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 955.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 956.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 957.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 958.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 959.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 960.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 961.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 962.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 963.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 964.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 965.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 966.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 967.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 968.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 969.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 970.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 971.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 972.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 973.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 974.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 975.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 976.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 977.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 978.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 979.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 980.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 981.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 982.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 983.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 984.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 990.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 991.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 992.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 993.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 995.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 996.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 997.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 998.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 999.wav

# %%
np.mean(list(predictions.values()))
# Out:
# 0.5541327993891731

# %% [markdown]
# Predict for negative segments

# %%
output_folder='../data/train_data/audio/0/'
wav_files = os.listdir(output_folder)

# %%
predictions.update(dict.fromkeys(wav_files, 0.0))

# %%
for file in wav_files:
    audio_path = Path(os.path.join(output_folder, file))
    recording = Recording(
        analyzer,
        audio_path,
        min_conf=0.0
    )
    recording.analyze()
    for detection in recording.detections:
        if detection['scientific_name']=='Scolopax rusticola':
            predictions[file] = detection['confidence']
# Out:
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1004.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1020.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1036.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1047.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1051.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1058.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1059.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1065.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1071.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1072.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1075.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1087.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1093.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1097.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1119.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1139.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1140.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1143.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1147.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1164.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1171.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1183.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1191.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1195.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1199.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1219.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1223.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1236.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1240.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1249.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1255.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1261.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1262.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1272.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1276.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1296.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1305.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1308.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1313.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1318.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1329.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1332.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1341.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1348.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1355.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1364.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1371.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1392.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1409.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1431.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1434.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1436.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1438.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1439.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1441.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1451.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1454.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1474.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1477.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1484.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1486.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1492.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1498.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1499.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1523.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1524.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1526.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1539.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1543.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1554.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1560.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1565.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1568.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1585.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1598.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1600.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1614.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1646.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1684.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1703.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1728.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1734.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1746.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1750.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1756.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1766.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1771.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1779.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1781.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1810.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1819.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1836.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1842.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1863.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1864.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1868.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1888.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1895.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1898.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1902.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1914.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1922.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1927.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1944.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1945.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1962.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1964.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1990.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_1991.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_304.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_316.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_327.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_349.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_365.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_379.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_384.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_401.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_403.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_415.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_430.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_441.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_443.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_447.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_456.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_461.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_467.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_470.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_476.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_506.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_511.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_512.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_515.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_528.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_566.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_570.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_573.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_574.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_586.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_598.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_622.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_628.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_631.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_659.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_669.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_676.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_687.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_711.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_713.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_716.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_732.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_749.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_774.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_780.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_782.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_785.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_786.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_789.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_791.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_793.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_795.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_796.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_808.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_814.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_833.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_853.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_873.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_887.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_888.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_900.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_902.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_911.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_912.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_918.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_921.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_949.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_956.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_959.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_964.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_977.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_985.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_988.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 3dBhE6_992.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1014.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1020.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1024.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1047.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1052.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1054.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1058.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1112.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1124.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1131.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1133.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1135.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1146.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1161.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1163.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1179.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1195.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1213.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1229.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1242.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1270.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1283.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1286.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1292.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1301.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1306.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1315.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1329.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1333.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1340.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1341.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1348.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1371.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1381.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1396.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1397.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1400.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1422.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1423.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1426.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1436.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_1441.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording 5da8q2_
wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_1960.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_1980.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_1988.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_302.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_303.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_305.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_307.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_326.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_333.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_343.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_353.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_359.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_365.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_367.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_370.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_371.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_385.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_402.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_403.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_414.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_419.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_431.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_439.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_449.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_462.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_471.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_480.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_521.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_530.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_538.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_567.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_568.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_578.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_589.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_601.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_609.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_621.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_623.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_624.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_637.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_644.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_650.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_663.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_665.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_677.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_685.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_691.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_723.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_738.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_740.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_743.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_762.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_777.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_778.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_812.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_816.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_821.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_822.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_832.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_836.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_839.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_852.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_867.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_876.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_879.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_894.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_899.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_903.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_904.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_906.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_912.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_913.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_925.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_942.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_952.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_967.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_969.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_970.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_973.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_980.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_985.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_986.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_988.wav
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording xPBJ0r_989.wav

# %%
np.save('holderried_predictions.npy', predictions)

# %%
sorted_keys = sorted(predictions.keys())

# Step 2: Extract scores and generate true labels
y_pred = [predictions[k] for k in sorted_keys]
y_true = [0 if len(k)>9 else 1 for k in sorted_keys]

# Step 3: Compute Average Precision
ap = average_precision_score(y_true, y_pred)
ap
# Out:
# 0.8945547437215977

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Only for binary classification (adjust for multi-class)
precision, recall, thr = precision_recall_curve(y_true, y_pred)

plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %%
plt.plot(thr,precision[:-1])
plt.ylabel("Precision")
plt.xlabel("Threshold")
# Out:
# Text(0.5, 0, 'Threshold')

# %%
plt.plot(thr, recall[:-1])
plt.ylabel("Recall")
plt.xlabel("Threshold")
# Out:
# Text(0.5, 0, 'Threshold')

# %%
#preds_negative = {k: predictions[k] for k in wav_files if k in predictions}
#preds_negative = np.array(list(preds_negative.values()))

# %%
# Sample data
x = thr
y1 = precision[:-1]            # First curve
y2 = recall[:-1]      # Second curve

# Create figure and first axis
fig, ax1 = plt.subplots()

# Plot the first line
color1 = 'tab:blue'
ax1.set_xlabel('Confidence threshold')
ax1.set_ylabel('Precision', color=color1)
ax1.plot(x, y1, color=color1)
ax1.tick_params(axis='y', labelcolor=color1)
ax1.grid(True) 
ax1.set_xlim([0, 1])
ax1.set_ylim([0, 1.05])

# Create second y-axis sharing the same x-axis
ax2 = ax1.twinx()
color2 = 'tab:red'
ax2.set_ylabel('Recall', color=color2)
ax2.plot(x, y2, color=color2)
ax2.tick_params(axis='y', labelcolor=color2)

# Optional: improve layout
fig.tight_layout()

plt.show()

# %%
f1 = 2*precision*recall/(precision+recall)

# %%
plt.plot(thr, f1[:-1], '-m')
plt.ylabel("f1")
plt.xlabel("Threshold")
plt.grid()

# %%
np.max(f1)
# Out:
# 0.8333679186553228

# %% [markdown]
# Map the values to uniformly spaced threshold values

# %%
from scipy.interpolate import interp1d

# %%
#thr_uniform = np.linspace(0, 1, 101)
thr_uniform = np.linspace(thr.min(), thr.max(), 100)

# %%
interpolator = interp1d(thr, f1[:-1], kind='linear')  # or 'cubic', 'quadratic', etc.
f1_score = interpolator(thr_uniform)

# %%
np.savez('holderried_f1.npz', thr=thr_uniform, f1=f1_score)

# %%
plt.plot(thr_uniform,f1_score)
plt.ylabel("f1")
plt.xlabel("Threshold")
plt.grid()
